# %%
from Seldyn import *

# %%
check_indices = [234, 218, 90, 226, 228, 236, 240, 248, 244, 98, 94, 242, 106, 100, 138, 222, 114, 102, 224, 112, 230, 232, 118, 220, 116, 120, 110, 124, 128, 122, 108, 126, 96, 92, 104, 238, 246]
for index in check_indices:
    print("Looping: "+str(index))
    in_filename = "CONTCAR-rY" + str(index) + "-temp.vasp"
    out_filename = "CONTCAR-rY" + str(index) + "-temp-out.vasp"
    seldynswitch(in_filename,out_filename)
# Out:
# Looping: 234
# Reading from file: CONTCAR-rY234-temp.vasp
# Writing to file: CONTCAR-rY234-temp-out.vasp
# Looping: 218
# Reading from file: CONTCAR-rY218-temp.vasp
# Writing to file: CONTCAR-rY218-temp-out.vasp
# Looping: 90
# Reading from file: CONTCAR-rY90-temp.vasp
# Writing to file: CONTCAR-rY90-temp-out.vasp
# Looping: 226
# Reading from file: CONTCAR-rY226-temp.vasp
# Writing to file: CONTCAR-rY226-temp-out.vasp
# Looping: 228
# Reading from file: CONTCAR-rY228-temp.vasp
# Writing to file: CONTCAR-rY228-temp-out.vasp
# Looping: 236
# Reading from file: CONTCAR-rY236-temp.vasp
# Writing to file: CONTCAR-rY236-temp-out.vasp
# Looping: 240
# Reading from file: CONTCAR-rY240-temp.vasp
# Writing to file: CONTCAR-rY240-temp-out.vasp
# Looping: 248
# Reading from file: CONTCAR-rY248-temp.vasp
# Writing to file: CONTCAR-rY248-temp-out.vasp
# Looping: 244
# Reading from file: CONTCAR-rY244-temp.vasp
# Writing to file: CONTCAR-rY244-temp-out.vasp
# Looping: 98
# ...
