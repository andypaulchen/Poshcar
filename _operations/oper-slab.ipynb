# %%
from Slab import *
from Perovskite import *
from Supercell import *
perovABX3("CsSnI.vasp", 6.41414, "Cs", "Sn", "I")
# Out:
# Writing to file: CsSnI.vasp

# %%
Supercell("CsSnI.vasp", "CsSnI-02.vasp", 2, 2, 2)
Slab("CsSnI-02.vasp", "CsSnI-02.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-03.vasp", 2, 2, 3)
Slab("CsSnI-03.vasp", "CsSnI-03.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-04.vasp", 2, 2, 4)
Slab("CsSnI-04.vasp", "CsSnI-04.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-05.vasp", 2, 2, 5)
Slab("CsSnI-05.vasp", "CsSnI-05.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-06.vasp", 2, 2, 6)
Slab("CsSnI-06.vasp", "CsSnI-06.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-07.vasp", 2, 2, 7)
Slab("CsSnI-07.vasp", "CsSnI-07.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-08.vasp", 2, 2, 8)
Slab("CsSnI-08.vasp", "CsSnI-08.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-09.vasp", 2, 2, 9)
Slab("CsSnI-09.vasp", "CsSnI-09.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-10.vasp", 2, 2, 10)
Slab("CsSnI-10.vasp", "CsSnI-10.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-11.vasp", 2, 2, 11)
Slab("CsSnI-11.vasp", "CsSnI-11.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-12.vasp", 2, 2, 12)
Slab("CsSnI-12.vasp", "CsSnI-12.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-13.vasp", 2, 2, 13)
Slab("CsSnI-13.vasp", "CsSnI-13.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-14.vasp", 2, 2, 14)
Slab("CsSnI-14.vasp", "CsSnI-14.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-15.vasp", 2, 2, 15)
Slab("CsSnI-15.vasp", "CsSnI-15.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-16.vasp", 2, 2, 16)
Slab("CsSnI-16.vasp", "CsSnI-16.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-17.vasp", 2, 2, 17)
Slab("CsSnI-17.vasp", "CsSnI-17.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-18.vasp", 2, 2, 18)
Slab("CsSnI-18.vasp", "CsSnI-18.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-19.vasp", 2, 2, 19)
Slab("CsSnI-19.vasp", "CsSnI-19.slab.vasp", 30)

Supercell("CsSnI.vasp", "CsSnI-20.vasp", 2, 2, 20)
Slab("CsSnI-20.vasp", "CsSnI-20.slab.vasp", 30)
# Out:
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-02.vasp
# Reading from file: CsSnI-02.vasp
# Writing to file: CsSnI-02.slab.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-03.vasp
# Reading from file: CsSnI-03.vasp
# Writing to file: CsSnI-03.slab.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-04.vasp
# Reading from file: CsSnI-04.vasp
# Writing to file: CsSnI-04.slab.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-05.vasp
# Reading from file: CsSnI-05.vasp
# Writing to file: CsSnI-05.slab.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-06.vasp
# Reading from file: CsSnI-06.vasp
# Writing to file: CsSnI-06.slab.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-07.vasp
# ...
