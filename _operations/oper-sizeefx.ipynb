# %%
from VacuumQD import *
from Perovskite import *
from Supercell import *
perovABX3("CsSnI.vasp", 6.41414, "Cs", "Sn", "I")

Supercell("CsSnI.vasp", "CsSnI-008.vasp", 2, 2, 2)
VacuumQD("CsSnI-008.vasp","CsSnI-008QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-012.vasp", 2, 2, 3)
VacuumQD("CsSnI-012.vasp","CsSnI-012QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-018.vasp", 2, 3, 3)
VacuumQD("CsSnI-018.vasp","CsSnI-018QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-036.vasp", 3, 3, 4)
VacuumQD("CsSnI-036.vasp","CsSnI-036QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-048.vasp", 3, 4, 4)
VacuumQD("CsSnI-048.vasp","CsSnI-048QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-064.vasp", 4, 4, 4)
VacuumQD("CsSnI-064.vasp","CsSnI-064QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-080.vasp", 4, 4, 5)
VacuumQD("CsSnI-080.vasp","CsSnI-080QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-100.vasp", 4, 5, 5)
VacuumQD("CsSnI-100.vasp","CsSnI-100QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-125.vasp", 5, 5, 5)
VacuumQD("CsSnI-125.vasp","CsSnI-125QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-150.vasp", 5, 5, 6)
VacuumQD("CsSnI-150.vasp","CsSnI-150QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-180.vasp", 5, 6, 6)
VacuumQD("CsSnI-180.vasp","CsSnI-180QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-216.vasp", 6, 6, 6)
VacuumQD("CsSnI-216.vasp","CsSnI-216QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-252.vasp", 6, 6, 7)
VacuumQD("CsSnI-252.vasp","CsSnI-252QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-294.vasp", 6, 7, 7)
VacuumQD("CsSnI-294.vasp","CsSnI-294QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-343.vasp", 7, 7, 7)
VacuumQD("CsSnI-343.vasp","CsSnI-343QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-392.vasp", 7, 7, 8)
VacuumQD("CsSnI-392.vasp","CsSnI-392QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-448.vasp", 7, 8, 8)
VacuumQD("CsSnI-448.vasp","CsSnI-448QD.vasp",30)

Supercell("CsSnI.vasp", "CsSnI-512.vasp", 8, 8, 8)
VacuumQD("CsSnI-512.vasp","CsSnI-512QD.vasp",30)
# Out:
# Writing to file: CsSnI.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-008.vasp
# Reading from file: CsSnI-008.vasp
# Separation parameter:  12.82828
# Writing to file: CsSnI-008QD.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-012.vasp
# Reading from file: CsSnI-012.vasp
# Separation parameter:  12.82828
# Writing to file: CsSnI-012QD.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-018.vasp
# Reading from file: CsSnI-018.vasp
# Separation parameter:  12.82828
# Writing to file: CsSnI-018QD.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-036.vasp
# Reading from file: CsSnI-036.vasp
# Separation parameter:  19.24242
# Writing to file: CsSnI-036QD.vasp
# Reading from file: CsSnI.vasp
# Converting: Fractional > Cartesian
# Writing to file: CsSnI-048.vasp
# ...

# %%
4 in [3,2,1]
# Out:
# False

# %%
from Supercell import *

# %%
Supercell("MAPbI3.vasp", "MAPBI3-s.vasp", 2, 2, 2)
# Out:
# Reading from file: MAPbI3.vasp
# Writing to file: MAPBI3-s.vasp

# %%
Supercell("MASnI3.vasp", "MASnI3-s.vasp", 2, 2, 2)
# Out:
# Reading from file: MASnI3.vasp
# Writing to file: MASnI3-s.vasp

# %%
from ElemSwitch import *

# %%
ElemSwitch("TETSn.vasp","TETSn.vasp")
# Out:
# Reading from file: TETSn.vasp
# List of elements:    I    Sn    C    H    N
# Number of Atoms:    12    4    4    24    4
# ...
# Reading from file: TETSn.vasp
# Which two elements do you want to switch?: H N
# Chosen atomic species to switch:  ['H', 'N']
# New Element Order:      I    Sn    C    N    H
# Number of Atoms:      12    4    4    4    24
# Writing to file: TETSn.vasp

# %%
from VacuumQD import *
VacuumQDPerov("QD-CsZnI3-008A.vasp", 5.533, ["Cs","Zn","I"], [2,2,2], 30, "A")
VacuumQDPerov("QD-CsZnI3-008B.vasp", 5.533, ["Cs","Zn","I"], [2,2,2], 30, "B")
VacuumQDPerov("QD-CsZnI3-027A.vasp", 5.533, ["Cs","Zn","I"], [3,3,3], 30, "A")
VacuumQDPerov("QD-CsZnI3-027B.vasp", 5.533, ["Cs","Zn","I"], [3,3,3], 30, "B")
VacuumQDPerov("QD-CsZnI3-064A.vasp", 5.533, ["Cs","Zn","I"], [4,4,4], 30, "A")
VacuumQDPerov("QD-CsZnI3-064B.vasp", 5.533, ["Cs","Zn","I"], [4,4,4], 30, "B")
VacuumQDPerov("QD-CsZnI3-125A.vasp", 5.533, ["Cs","Zn","I"], [5,5,5], 30, "A")
VacuumQDPerov("QD-CsZnI3-125B.vasp", 5.533, ["Cs","Zn","I"], [5,5,5], 30, "B")
VacuumQDPerov("QD-CsZnI3-216A.vasp", 5.533, ["Cs","Zn","I"], [6,6,6], 30, "A")
VacuumQDPerov("QD-CsZnI3-216B.vasp", 5.533, ["Cs","Zn","I"], [6,6,6], 30, "B")
VacuumQDPerov("QD-CsZnI3-343A.vasp", 5.533, ["Cs","Zn","I"], [7,7,7], 30, "A")
VacuumQDPerov("QD-CsZnI3-343B.vasp", 5.533, ["Cs","Zn","I"], [7,7,7], 30, "B")
VacuumQDPerov("QD-CsZnI3-512A.vasp", 5.533, ["Cs","Zn","I"], [8,8,8], 30, "A")
VacuumQDPerov("QD-CsZnI3-512B.vasp", 5.533, ["Cs","Zn","I"], [8,8,8], 30, "B")
VacuumQDPerov("QD-CsZnI3-729A.vasp", 5.533, ["Cs","Zn","I"], [9,9,9], 30, "A")
VacuumQDPerov("QD-CsZnI3-729B.vasp", 5.533, ["Cs","Zn","I"], [9,9,9], 30, "B")
VacuumQDPerov("QD-CsZnI3-999A.vasp", 5.533, ["Cs","Zn","I"], [10,10,10], 30, "A")
VacuumQDPerov("QD-CsZnI3-999B.vasp", 5.533, ["Cs","Zn","I"], [10,10,10], 30, "B")
# Out:
# Converting: Fractional > Cartesian
# Separation parameter:  11.066
# List of elements (clean cell):    I    Zn    Cs
# Number of atoms per element:    24    8    8
# ...
# List of elements (with dopant): I    Zn    Cs
# Number of atoms per element: 6    1    8
# Writing to file: QD-CsZnI3-008A.vasp
# Converting: Fractional > Cartesian
# Separation parameter:  11.066
# List of elements (clean cell):    I    Zn    Cs
# Number of atoms per element:    24    8    8
# ...
# List of elements (with dopant): I    Zn    Cs
# Number of atoms per element: 12    8    1
# Writing to file: QD-CsZnI3-008B.vasp
# Converting: Fractional > Cartesian
# Separation parameter:  16.599
# List of elements (clean cell):    I    Zn    Cs
# Number of atoms per element:    81    27    27
# ...
# List of elements (with dopant): I    Zn    Cs
# Number of atoms per element: 36    8    27
# Writing to file: QD-CsZnI3-027A.vasp
# Converting: Fractional > Cartesian
# Separation parameter:  16.599
# ...

# %%
from VacuumQD import *
from Perovskite import *
from Supercell import *

VacuumQD("size-effects/Notilt.vasp","size-effects/Notilt-111QD.vasp",30)

Supercell("size-effects/Notilt.vasp", "size-effects/Notilt-222.vasp", 2, 2, 2)
VacuumQD("size-effects/Notilt-222.vasp","size-effects/Notilt-222QD.vasp",30)

Supercell("size-effects/Notilt.vasp", "size-effects/Notilt-333.vasp", 3, 3, 3)
VacuumQD("size-effects/Notilt-333.vasp","size-effects/Notilt-333QD.vasp",30)

VacuumQD("size-effects/Yestilt.vasp","size-effects/Yestilt-111QD.vasp",30)

Supercell("size-effects/Yestilt.vasp", "size-effects/Yestilt-222.vasp", 2, 2, 2)
VacuumQD("size-effects/Yestilt-222.vasp","size-effects/Yestilt-222QD.vasp",30)

Supercell("size-effects/Yestilt.vasp", "size-effects/Yestilt-333.vasp", 3, 3, 3)
VacuumQD("size-effects/Yestilt-333.vasp","size-effects/Yestilt-333QD.vasp",30)
# Out:
# Reading from file: size-effects/Notilt.vasp
# Converting: Fractional > Cartesian
# Separation parameter:  12.6298999786
# Writing to file: size-effects/Notilt-111QD.vasp
# Reading from file: size-effects/Notilt.vasp
# Converting: Fractional > Cartesian
# Writing to file: size-effects/Notilt-222.vasp
# Reading from file: size-effects/Notilt-222.vasp
# Separation parameter:  25.2598
# Writing to file: size-effects/Notilt-222QD.vasp
# Reading from file: size-effects/Notilt.vasp
# Converting: Fractional > Cartesian
# Writing to file: size-effects/Notilt-333.vasp
# Reading from file: size-effects/Notilt-333.vasp
# Separation parameter:  37.8897
# Writing to file: size-effects/Notilt-333QD.vasp
# Reading from file: size-effects/Yestilt.vasp
# Converting: Fractional > Cartesian
# Separation parameter:  11.922347068828925
# Writing to file: size-effects/Yestilt-111QD.vasp
# Reading from file: size-effects/Yestilt.vasp
# Converting: Fractional > Cartesian
# ...
